# %% [markdown]
# # Getting Started
# This tutorial demonstrates the configuration and use of a simple BSK-RL environment.
# BSK-RL and dependencies should already be installed at this point (see [Installation](../install.rst)
# if you haven't installed the package yet).
#
# ## Load Modules
# In this tutorial, the environment will be created with `gym.make`, so it is necessary to
# import the top-level `bsk_rl` module as well as `gym` and `bsk_rl` components.

# %%
import gymnasium as gym
import numpy as np
from bsk_rl import act, data, obs, scene, sats
from bsk_rl.sim import dyn, fsw

from Basilisk.architecture import bskLogging
bskLogging.setDefaultLogLevel(bskLogging.BSK_WARNING)

# %% [markdown]
# If no errors were raised, you have a functional installation of `bsk_rl`.
#
# ## Configure the Satellite
# [Satellites](../api_reference/sats/index.rst) are configurable agents in the environment.
# To make a new environment, start by specifying the [observations](../api_reference/obs/index.rst)
# and [actions](../api_reference/act/index.rst) of a satellite type, as well as the underlying
# Basilisk [simulation](../api_reference/sim/index.rst) models used by the satellite.

# %%
class MyScanningSatellite(sats.AccessSatellite):
    observation_spec = [
        obs.SatProperties(
            dict(prop="storage_level_fraction"),
            dict(prop="battery_charge_fraction")
        ),
        obs.Eclipse(),
    ]
    action_spec = [
        act.Scan(duration=60.0),  # Scan for 1 minute
        act.Charge(duration=600.0),  # Charge for 10 minutes
    ]
    dyn_type = dyn.TargetScDynModel
    fsw_type = fsw.ScTargetImagingModel

# %% [markdown]
# Based on this class specification, a list of configurable parameters for the satellite
# can be generated.

# %%
MyScanningSatellite.default_sat_args()
# Out:
# {'hs_min': 0.0,
#  'maxCounterValue': 4,
#  'thrMinFireTime': 0.02,
#  'desatAttitude': 'sun',
#  'controlAxes_B': [1, 0, 0, 0, 1, 0, 0, 0, 1],
#  'thrForceSign': 1,
#  'K': 7.0,
#  'Ki': -1,
#  'P': 35.0,
#  'imageAttErrorRequirement': 0.01,
#  'imageRateErrorRequirement': None,
#  'inst_pHat_B': [0, 0, 1],
#  'utc_init': 'this value will be set by the world model',
#  'batteryStorageCapacity': 288000.0,
#  'storedCharge_Init': <function bsk_rl.sim.dyn.BasicDynamicsModel.<lambda>()>,
#  'disturbance_vector': None,
#  'dragCoeff': 2.2,
#  'imageTargetMaximumRange': -1,
#  'instrumentBaudRate': 8000000.0,
#  'instrumentPowerDraw': -30.0,
#  'basePowerDraw': 0.0,
#  'wheelSpeeds': <function bsk_rl.sim.dyn.BasicDynamicsModel.<lambda>()>,
#  'maxWheelSpeed': inf,
#  'u_max': 0.2,
#  'rwBasePower': 0.4,
#  'rwMechToElecEfficiency': 0.0,
#  'rwElecToMechEfficiency': 0.5,
#  'panelArea': 1.0,
#  'panelEfficiency': 0.2,
#  'nHat_B': array([ 0,  0, -1]),
#  'mass': 330,
#  'width': 1.38,
#  'depth': 1.04,
#  'height': 1.58,
#  'sigma_init': <function bsk_rl.sim.dyn.BasicDynamicsModel.<lambda>()>,
#  'omega_init': <function bsk_rl.sim.dyn.BasicDynamicsModel.<lambda>()>,
#  'rN': None,
#  'vN': None,
#  'oe': <function bsk_rl.utils.orbital.random_orbit(i: Optional[float] = 45.0, alt: float = 500, r_body: float = 6371, e: float = 0, Omega: Optional[float] = None, omega: Optional[float] = 0, f: Optional[float] = None) -> Basilisk.utilities.orbitalMotion.ClassicElements>,
#  'mu': 398600436000000.0,
#  'dataStorageCapacity': 160000000.0,
#  'storageUnitValidCheck': False,
#  'storageInit': 0,
#  'thrusterPowerDraw': 0.0,
#  'transmitterBaudRate': -8000000.0,
#  'transmitterNumBuffers': 100,
#  'transmitterPowerDraw': -15.0}

# %% [markdown]
# When instantiating a satellite, these parameters can be overriden with a constant or
# rerandomized every time the environment is reset using the ``sat_args`` dictionary.

# %%
sat_args = {}

# Set some parameters as constants
sat_args["imageAttErrorRequirement"] = 0.05
sat_args["dataStorageCapacity"] = 1e10
sat_args["instrumentBaudRate"] = 1e7
sat_args["storedCharge_Init"] = 50000.0

# Randomize the initial storage level on every reset
sat_args["storageInit"] = lambda: np.random.uniform(0.25, 0.75) * 1e10

# Make the satellite
sat = MyScanningSatellite(name="EO1", sat_args=sat_args)

# %% [markdown]
# ## Making the Environment
# For this example, we will be using the single-agent [SatelliteTasking](../api_reference/index.rst)
# environment. Along with passing the satellite that we configured, the environment takes
# a [scenario](../api_reference/scene/index.rst), which defines the environment the
# satellite is acting in, and a [rewarder](../api_reference/data/index.rst), which defines
# how data collected from the scenario is rewarded.

# %%
env = gym.make(
    "SatelliteTasking-v1",
    satellite=sat,
    scenario=scene.UniformNadirScanning(),
    rewarder=data.ScanningTimeReward(),
    time_limit=5700.0,  # approximately 1 orbit
    log_level="INFO",
    disable_env_checker=True,
)
# Out:
# 2025-01-29 13:09:00,720                                WARNING    Creating logger for new env on PID=58980. Old environments in process may now log times incorrectly.

# %% [markdown]
# ## Interacting with the Environment
#
# First, the environment is reset.

# %%
observation, info = env.reset(seed=1)
# Out:
# 2025-01-29 13:09:02,395 gym                            INFO       Resetting environment with seed=1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 observation, info = env.reset(seed=1)
#
# File ~/Repositories/bsk_rl/.venv/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:61, in OrderEnforcing.reset(self, **kwargs)
#      59 """Resets the environment with `kwargs`."""
#      60 self._has_reset = True
# ---> 61 return self.env.reset(**kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/gym.py:275, in GeneralSatelliteTasking.reset(self, seed, options)
#     272     self.rewarder.create_data_store(satellite)
#     273     satellite.reset_pre_sim_init()
# --> 275 self.simulator = Simulator(
#     276     self.satellites,
#     277     self.world_type,
#     278     self.world_args,
#     279     sim_rate=self.sim_rate,
#     280     max_step_duration=self.max_step_duration,
#     281     time_limit=self.time_limit,
#     282 )
#     284 self.scenario.reset_post_sim_init()
#     285 self.rewarder.reset_post_sim_init()
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/simulator.py:57, in Simulator.__init__(self, satellites, world_type, world_args, sim_rate, max_step_duration, time_limit)
#      55 for satellite in self.satellites:
#      56     satellite.set_simulator(self)
# ---> 57     self.dynamics_list[satellite.name] = satellite.set_dynamics(self.sim_rate)
#      58     self.fsw_list[satellite.name] = satellite.set_fsw(self.sim_rate)
#      60 self.InitializeSimulation()
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sats/satellite.py:174, in Satellite.set_dynamics(self, dyn_rate)
#     163 def set_dynamics(self, dyn_rate: float) -> "dyn.DynamicsModel":
#     164     """Create dynamics model; called during simulator initialization.
#     165
#     166     Args:
#    (...)
#     172     :meta private:
#     173     """
# --> 174     dynamics = self.dyn_type(self, dyn_rate, **self.sat_args)
#     175     self.dynamics = proxy(dynamics)
#     176     return dynamics
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:1048, in ContinuousImagingDynModel.__init__(self, *args, **kwargs)
#    1040 def __init__(self, *args, **kwargs) -> None:
#    1041     """Equips the satellite for continuous nadir imaging.
#    1042
#    1043     Equips satellite with an instrument, storage unit, and transmitter
#    (...)
#    1046     center of the Earth for nadir imaging.
#    1047     """
# -> 1048     super().__init__(*args, **kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:778, in ImagingDynModel.__init__(self, *args, **kwargs)
#     771 def __init__(self, *args, **kwargs) -> None:
#     772     """Equips the satellite with an instrument, storage unit, and transmitter.
#     773
#     774     This dynamics model is used with :class:`~bsk_rl.sats.ImagingSatellite`. It
#     775     provides the satellite with the ability to take images of a point target. To
#     776     enable downlink, use :class:`GroundStationDynModel` and :class:`~bsk_rl.sim.world.GroundStationWorldModel`.
#     777     """
# --> 778     super().__init__(*args, **kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:192, in BasicDynamicsModel.__init__(self, *args, **kwargs)
#     174 def __init__(self, *args, **kwargs) -> None:
#     175     """A dynamics model with a basic feature set.
#     176
#     177     Includes the following:
#    (...)
#     190         **kwargs: Passed to superclass
#     191     """
# --> 192     super().__init__(*args, **kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:128, in DynamicsModel.__init__(self, satellite, dyn_rate, priority, **kwargs)
#     126 # Initialize all modules and write init one-time messages
#     127 self.scObject: spacecraft.Spacecraft
# --> 128 self._setup_dynamics_objects(**kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:791, in ImagingDynModel._setup_dynamics_objects(self, **kwargs)
#     790 def _setup_dynamics_objects(self, **kwargs) -> None:
# --> 791     super()._setup_dynamics_objects(**kwargs)
#     792     self.setup_instrument_power_sink(**kwargs)
#     793     self.setup_transmitter_power_sink(**kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:272, in BasicDynamicsModel._setup_dynamics_objects(self, **kwargs)
#     271 def _setup_dynamics_objects(self, **kwargs) -> None:
# --> 272     self.setup_spacecraft_hub(**kwargs)
#     273     self.setup_drag_effector(**kwargs)
#     274     self.setup_reaction_wheel_dyn_effector(**kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/utils/functional.py:66, in default_args.<locals>.inner_dec.<locals>.inner(*args, **kwargs)
#      64 @wraps(func)
#      65 def inner(*args: P.args, **kwargs: P.kwargs) -> T:
# ---> 66     return func(*args, **kwargs)
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:361, in BasicDynamicsModel.setup_spacecraft_hub(self, mass, width, depth, height, sigma_init, omega_init, oe, rN, vN, mu, priority, **kwargs)
#     355 self.scObject.hub.v_CN_NInit = unitTestSupport.np2EigenVectorXd(vN)
#     357 self.simulator.AddModelToTask(
#     358     self.task_name, self.scObject, ModelPriority=priority
#     359 )
# --> 361 self.setup_gravity_bodies()
#     362 self.setup_disturbance_torque(**kwargs)
#     363 self.setup_density_model()
#
# File ~/Repositories/bsk_rl/src/bsk_rl/sim/dyn.py:1218, in TargetScDynModel.setup_gravity_bodies(self)
#    1216 def setup_gravity_bodies(self) -> None:
#    1217     """Set up gravitational bodies from the :class:`~bsk_rl.sim.world.WorldModel` to included in the simulation."""
# -> 1218     self.imagingTarget.gravField.gravBodies = spacecraft.GravBodyVector(
#    1219         list(self.world.gravFactory.gravBodies.values())
#    1220     )
#
# AttributeError: 'TargetScDynModel' object has no attribute 'imagingTarget'

# %% [markdown]
# Next, we take the scan action (`action=0`) a few times. This allows for the satellite to
# settle its attitude in the nadir pointing mode to satisfy imaging conditions. Note that
# the logs show little or no data accumulated in the first two steps as it settles, but
# achieves 60 reward (corresponding to 60 seconds of imaging) by the third step.

# %%
print("Initial data level:", observation[0], "(randomized by sat_args)")
for _ in range(3):
    observation, reward, terminated, truncated, info = env.step(action=0)
print("  Final data level:", observation[0])

# %% [markdown]
# The observation reflects the increase in stored data. The first element, corresponding
# to `storage_level_fraction`, starts at a random value set by the `storageInit` function
# in `sat_args` and increases based on the time spent imaging.
#
# Finally, the charging mode is tasked repeatedly in 10-minute increments until the
# environment time limit is reached.

# %%
while not truncated:
    observation, reward, terminated, truncated, info = env.step(action=1)
    print(f"Charge level: {observation[1]:.3f} ({env.unwrapped.simulator.sim_time:.1f} seconds)\n\tEclipse: start: {observation[2]:.1f} end: {observation[3]:.1f}")

# %% [markdown]
# It is observed that the battery decrease while the satellite is in eclipse, but once the
# satellite is out of eclipse, the battery quickly increases to full charge.
